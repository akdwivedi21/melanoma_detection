# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pathlib
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import PIL

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

from tensorflow.keras.preprocessing.image import load_img

# %%
# "CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration"
data_dir_train = pathlib.Path("gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
data_dir_test = pathlib.Path('gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/')

# %%
os.listdir("gdrive/MyDrive/CNN_assignment/")
# Out:
# ['Skin cancer ISIC The International Skin Imaging Collaboration']

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
#Visualize one instance of all the class present in the dataset.

#image_dataset_from_directory() will return a tf.data.Dataset that yields batches of images from the subdirectories.
#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes), representing a one-hot encoding of the class index.
image_dataset = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,image_size=(180,180),
                                                                    label_mode='categorical',seed=123)

#all the classes of Skin Cancer
class_names = image_dataset.class_names

#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))

#Visualize image
plt.figure(figsize=(15,15))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")
# Out:
# Found 2791 files belonging to 9 classes.

# %%
def class_distribution_count(directory):

    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))

    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]

    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0                    melanoma           438
# 1        seborrheic keratosis            77
# 2                       nevus           357
# 3     squamous cell carcinoma           181
# 4        basal cell carcinoma           376
# 5  pigmented benign keratosis           462
# 6              dermatofibroma            95
# 7             vascular lesion           139
# 8           actinic keratosis           114

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Image", y="Class", data=df,
            label="Class")
# Out:
# <Axes: xlabel='No. of Image', ylabel='Class'>

# %%
#install Augmentor
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %%
path_to_training_dataset="gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)  #Adding 500 samples per class to make sure that none of the classes are sparse
# Out:
# Initialised with 114 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79E5462CB5B0>: 100%|██████████| 500/500 [00:22<00:00, 22.70 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79E549B92F80>: 100%|██████████| 500/500 [00:23<00:00, 21.06 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79E54634F940>: 100%|██████████| 500/500 [00:21<00:00, 23.10 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=2313x1985 at 0x79E549B717E0>: 100%|██████████| 500/500 [01:57<00:00,  4.25 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x79E549B917E0>: 100%|██████████| 500/500 [01:40<00:00,  4.96 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79E54EEBF340>: 100%|██████████| 500/500 [00:22<00:00, 22.68 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x79E549CAF4C0>: 100%|██████████| 500/500 [00:47<00:00, 10.46 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x79E549C694E0>: 100%|██████████| 500/500 [00:24<00:00, 20.39 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79E55E146B60>: 100%|██████████| 500/500 [00:22<00:00, 22.41 Samples/s]

# %%
#Count total number of image generated by Augmentor.
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 5052

# %%
# train dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(180,180), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)

#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes),
#representing a one-hot encoding of the class index.
# Out:
# Found 7291 files belonging to 9 classes.
# Using 5833 files for training.

# %%
# validation dataset
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(180,180), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 7291 files belonging to 9 classes.
# Using 1458 files for validation.

# %%
#tf.data.experimental.AUTOTUNE defines appropriate number of processes that are free for working.

#`Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.

#`Dataset.prefetch()` overlaps data preprocessing and model execution while training.


AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 89, 89, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 128)               6553728
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6648137 (25.36 MB)
# Trainable params: 6648137 (25.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# vizualizing the model
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
#Compile the Model

#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %%
# Train the model
epochs = 30
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/30
# 183/183 [==============================] - ETA: 0s - loss: 2.0025 - accuracy: 0.2337
# Epoch 1: val_accuracy improved from -inf to 0.30658, saving model to model.h5
# 183/183 [==============================] - 489s 2s/step - loss: 2.0025 - accuracy: 0.2337 - val_loss: 1.7610 - val_accuracy: 0.3066
# Epoch 2/30
# 183/183 [==============================] - ETA: 0s - loss: 1.6651 - accuracy: 0.3676
# Epoch 2: val_accuracy improved from 0.30658 to 0.44307, saving model to model.h5
# 183/183 [==============================] - 426s 2s/step - loss: 1.6651 - accuracy: 0.3676 - val_loss: 1.4748 - val_accuracy: 0.4431
# Epoch 3/30
# 183/183 [==============================] - ETA: 0s - loss: 1.4631 - accuracy: 0.4507
# Epoch 3: val_accuracy improved from 0.44307 to 0.50000, saving model to model.h5
# 183/183 [==============================] - 440s 2s/step - loss: 1.4631 - accuracy: 0.4507 - val_loss: 1.3063 - val_accuracy: 0.5000
# Epoch 4/30
# 183/183 [==============================] - ETA: 0s - loss: 1.3349 - accuracy: 0.5056
# Epoch 4: val_accuracy improved from 0.50000 to 0.55693, saving model to model.h5
# 183/183 [==============================] - 420s 2s/step - loss: 1.3349 - accuracy: 0.5056 - val_loss: 1.1768 - val_accuracy: 0.5569
# Epoch 5/30
# 183/183 [==============================] - ETA: 0s - loss: 1.2085 - accuracy: 0.5608
# Epoch 5: val_accuracy improved from 0.55693 to 0.61866, saving model to model.h5
# 183/183 [==============================] - 414s 2s/step - loss: 1.2085 - accuracy: 0.5608 - val_loss: 1.0532 - val_accuracy: 0.6187
# Epoch 6/30
# 183/183 [==============================] - ETA: 0s - loss: 1.1000 - accuracy: 0.5975
# Epoch 6: val_accuracy did not improve from 0.61866
# 183/183 [==============================] - 427s 2s/step - loss: 1.1000 - accuracy: 0.5975 - val_loss: 1.0700 - val_accuracy: 0.6125
# Epoch 7/30
# 183/183 [==============================] - ETA: 0s - loss: 1.0259 - accuracy: 0.6304
# Epoch 7: val_accuracy improved from 0.61866 to 0.65295, saving model to model.h5
# 183/183 [==============================] - 429s 2s/step - loss: 1.0259 - accuracy: 0.6304 - val_loss: 0.9438 - val_accuracy: 0.6529
# Epoch 8/30
# 183/183 [==============================] - ETA: 0s - loss: 0.9565 - accuracy: 0.6609
# Epoch 8: val_accuracy improved from 0.65295 to 0.67353, saving model to model.h5
# 183/183 [==============================] - 430s 2s/step - loss: 0.9565 - accuracy: 0.6609 - val_loss: 0.9152 - val_accuracy: 0.6735
# Epoch 9/30
# 183/183 [==============================] - ETA: 0s - loss: 0.8882 - accuracy: 0.6751
# Epoch 9: val_accuracy improved from 0.67353 to 0.71742, saving model to model.h5
# 183/183 [==============================] - 427s 2s/step - loss: 0.8882 - accuracy: 0.6751 - val_loss: 0.7888 - val_accuracy: 0.7174
# Epoch 10/30
# 183/183 [==============================] - ETA: 0s - loss: 0.8596 - accuracy: 0.6871
# Epoch 10: val_accuracy improved from 0.71742 to 0.72634, saving model to model.h5
# 183/183 [==============================] - 424s 2s/step - loss: 0.8596 - accuracy: 0.6871 - val_loss: 0.7439 - val_accuracy: 0.7263
# Epoch 11/30
# 183/183 [==============================] - ETA: 0s - loss: 0.7599 - accuracy: 0.7298
# Epoch 11: val_accuracy improved from 0.72634 to 0.74691, saving model to model.h5
# 183/183 [==============================] - 426s 2s/step - loss: 0.7599 - accuracy: 0.7298 - val_loss: 0.7532 - val_accuracy: 0.7469
# Epoch 12/30
# 183/183 [==============================] - ETA: 0s - loss: 0.7161 - accuracy: 0.7370
# Epoch 12: val_accuracy did not improve from 0.74691
# 183/183 [==============================] - 422s 2s/step - loss: 0.7161 - accuracy: 0.7370 - val_loss: 0.8041 - val_accuracy: 0.7270
# Epoch 13/30
# 183/183 [==============================] - ETA: 0s - loss: 0.6601 - accuracy: 0.7612
# Epoch 13: val_accuracy did not improve from 0.74691
# 183/183 [==============================] - 430s 2s/step - loss: 0.6601 - accuracy: 0.7612 - val_loss: 0.7191 - val_accuracy: 0.7339
# Epoch 14/30
# 183/183 [==============================] - ETA: 0s - loss: 0.6293 - accuracy: 0.7631
# Epoch 14: val_accuracy improved from 0.74691 to 0.77572, saving model to model.h5
# 183/183 [==============================] - 425s 2s/step - loss: 0.6293 - accuracy: 0.7631 - val_loss: 0.6831 - val_accuracy: 0.7757
# Epoch 15/30
# 183/183 [==============================] - ETA: 0s - loss: 0.5704 - accuracy: 0.7960
# Epoch 15: val_accuracy did not improve from 0.77572
# 183/183 [==============================] - 426s 2s/step - loss: 0.5704 - accuracy: 0.7960 - val_loss: 0.6479 - val_accuracy: 0.7709
# Epoch 16/30
# 183/183 [==============================] - ETA: 0s - loss: 0.5571 - accuracy: 0.7943
# Epoch 16: val_accuracy improved from 0.77572 to 0.82030, saving model to model.h5
# 183/183 [==============================] - 412s 2s/step - loss: 0.5571 - accuracy: 0.7943 - val_loss: 0.5836 - val_accuracy: 0.8203
# Epoch 17/30
# 183/183 [==============================] - ETA: 0s - loss: 0.4812 - accuracy: 0.8184
# Epoch 17: val_accuracy did not improve from 0.82030
# 183/183 [==============================] - 412s 2s/step - loss: 0.4812 - accuracy: 0.8184 - val_loss: 0.6186 - val_accuracy: 0.7853
# Epoch 18/30
# 183/183 [==============================] - ETA: 0s - loss: 0.5108 - accuracy: 0.8123
# Epoch 18: val_accuracy did not improve from 0.82030
# 183/183 [==============================] - 425s 2s/step - loss: 0.5108 - accuracy: 0.8123 - val_loss: 0.5547 - val_accuracy: 0.8134
# Epoch 19/30
# 183/183 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.8143
# Epoch 19: val_accuracy did not improve from 0.82030
# 183/183 [==============================] - 427s 2s/step - loss: 0.5189 - accuracy: 0.8143 - val_loss: 0.5764 - val_accuracy: 0.8059
# Epoch 20/30
# 183/183 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.8263
# Epoch 20: val_accuracy did not improve from 0.82030
# 183/183 [==============================] - 428s 2s/step - loss: 0.4668 - accuracy: 0.8263 - val_loss: 0.5931 - val_accuracy: 0.8080
# Epoch 21/30
# 183/183 [==============================] - ETA: 0s - loss: 0.4292 - accuracy: 0.8371
# Epoch 21: val_accuracy did not improve from 0.82030
# 183/183 [==============================] - 423s 2s/step - loss: 0.4292 - accuracy: 0.8371 - val_loss: 0.6038 - val_accuracy: 0.7970
# Epoch 21: early stopping

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )
# Out:
# 1/1 [==============================] - 0s 236ms/step
# Actual Class basal cell carcinoma
# Predictive Class pigmented benign keratosis

# %%
### Conclusion
#1. Train score is 0.8371  and validation Score is 0.7970 .

# %% [markdown]
# # New section
